# %% [markdown]
# # Data Analytics with AI – Tableau Capstone Project
#
# ## 📈 Project Title
# *A concise, user-facing name (e.g., "Understanding Hospital Bed Occupancy Trends in the UK")*
#
# ---
#
# ## 📁 Project Overview
#
# This project uses **Tableau** to explore and visualise [dataset topic], transforming complex data into intuitive, interactive dashboards for business stakeholders.
#
# It aims to provide insights into [problem area] and guide decision-making for [target audience].
#
# ---
#
# ## 🧠 Business Problem
#
# - **Domain**: e.g., healthcare, finance, logistics
# - **Problem Framing**: Describe the core challenge the dashboard addresses
# - **Outcome Expected**: What should the viewer learn, decide, or act on?
#
# ---
#
# ## 📊 Dataset Info
#
# - **Source**: [dataset link or description]
# - **Format**: e.g., CSV, Excel, SQL
# - **Size**: e.g., 10,000 rows, 50 columns
# - **Cleaning**: Briefly explain steps taken in Excel, Python, or Tableau Prep
#
# ---
#
# ## 🧰 Tools & Features Used
#
# - **Tableau Desktop (Free Trial or Public)**
# - Tableau features used:
#   - Calculated fields
#   - Parameters
#   - Filters and slicers
#   - Dual axis charts
#   - Dashboard navigation buttons
# - AI support:
#   - Used ChatGPT or other AI to generate insight summaries or metric suggestions
#
# ---
#
# ## 📺 Dashboard Overview
#
# List and describe each page or key visual:
#
# 1. **Overview Page** – High-level KPIs
# 2. **Trend Page** – Time series and filters by location/group
# 3. **Insights Page** – Outliers, benchmarks, or segmented views
# 4. **Recommendations** – Story-style narrative or summary
#
# ---
#
# ## 🔍 Key Insights
#
# - [Example] Occupancy dropped by 18% post-lockdown, then surged
# - [Example] Facilities in Region B consistently underperform in staffing
# - [Example] Waiting time correlates with patient satisfaction score
#
# ---
#
# ## 🎯 Learning Outcomes Mapping
#
# | LO | Description | How Met in Tableau |
# |----|-------------|---------------------|
# | LO1 | Stats & Theory | Calculated averages, trends, distributions |
# | LO2 | Tools & Practice | Data cleaning, parameters, filters, story features |
# | LO3 | Problem Solving | Applied to healthcare access issue |
# | LO4 | AI Support | AI used for insight framing or narrative writing |
# | LO5 | Data Handling | Pre-cleaning done; filters, groups used in Tableau |
# | LO6 | Ethics | Discussed in README – anonymised, domain aware |
# | LO7 | Research Plan | Dashboard layout follows clear design logic |
# | LO8 | Communication | Storytelling pages + interactive visuals |
# | LO9 | Domain Use | Deep dive into specific sector problem |
# | LO10 | Maintenance | Can be updated with new data; roadmap included |
# | LO11 | Professional Growth | Reflected on Tableau learning curve + AI integration |
#
# ---
#
# ## 🔧 Challenges & Reflections
#
# - [Example] Creating dual-axis visualisation took time to learn
# - [Example] Data from two sources required blending and deduplication
# - [Example] AI helped but needed manual review to avoid hallucinations
#
# ---
#
# ## 🔮 Future Improvements
#
# - Automate data updates from Google Sheets
# - Add region-level drilldowns
# - Export story dashboards as PDF reports for offline sharing
#
# ---
#
# ## 📎 Files Submitted
#
# - `.twbx` Tableau workbook file
# - `README.md`
# - `data/` folder if applicable
# - `images/` screenshots of key visuals
